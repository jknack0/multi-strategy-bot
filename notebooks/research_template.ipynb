# %% [markdown]
# # Research Template
#
# Use this notebook for strategy research and exploration.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from config.settings import *
from config.constants import *
from data.questdb_client import QuestDBClient
from indicators.vwap import VWAP
from indicators.bollinger import BollingerBands
from indicators.atr import ATR
from indicators.vix_regime import VIXRegimeClassifier
from backtesting.backtest_engine import BacktestEngine
from backtesting.metrics import compute_all_metrics
from backtesting.monte_carlo import MonteCarloSimulator
from backtesting.cpcv_validator import CPCVValidator

# %% [markdown]
# ## Load Data

# %%
# Load data from QuestDB
# qdb = QuestDBClient()
# df = qdb.get_bars('MES', '1min')
# df.head()

# %% [markdown]
# ## Compute Indicators

# %%
# Example: compute Bollinger Bands on loaded data
# bb = BollingerBands(period=20, num_std=2.0)
# bb_values = [bb.update(c) for c in df['close']]
# bb_df = pd.DataFrame([v for v in bb_values if v is not None])

# %% [markdown]
# ## Backtest

# %%
# engine = BacktestEngine(symbol='MES')
# engine.load_data(df)
# engine.set_signals(entries, exits)
# results = engine.run()
# print(results)
